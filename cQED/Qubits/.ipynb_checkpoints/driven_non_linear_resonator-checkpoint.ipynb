# %%
from qutip import *

# %%
import sys 
import os
sys.path.append(os.path.abspath("C:\Users\User\Documents\GitHub/colormap/"))
import colormaps as cmaps

# %%
import numpy as np
import scipy.constants as cs
import scipy.special as ss
from matplotlib import pyplot as plt
from matplotlib import cm
sys.path.append(os.path.abspath("C:\Users\User\Documents\Github/"))
from qkit.qkit.gui.notebook.Progress_Bar import Progress_Bar as pb
from scipy.integrate import dblquad
from scipy import integrate

# %matplotlib inline

# %%
#customized plots:
import matplotlib 
matplotlib.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
matplotlib.rc('text', usetex=True)

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}
matplotlib.rc('font', **font)
matplotlib.rcParams['figure.figsize'] = (8.0,5.0)
matplotlib.rcParams['savefig.dpi'] = 200
matplotlib.rcParams['legend.shadow'] = False
matplotlib.rcParams['savefig.bbox'] = 'tight'


cmap_virdis = cmaps.viridis.colors

# %%
labelsize = 27

# %%
mu_0 = cs.mu_0
mu_B = cs.physical_constants['Bohr magneton'][0]   #Bohr magneton in SI units
k_b = cs.k

# %%
wc = 1.0  * 2 * np.pi   # cavity frequency
#wa = 1.0  * 2 * np.pi  # atom frequency
#g  = 0.05 * 2 * np.pi  # coupling strength
kappa = 5 * 10**-4          # cavity dissipation rate
gamma = 0.00           # atom dissipation rate
alpha = 2
N = 3*alpha                # number of cavity fock states
n_th_a = 0.0           # temperature in frequency units
use_rwa = True

tlist = np.linspace(0,1000,300)

# %%
# intial state
psi0 = tensor(basis(N,0))    # start with a cavity in vacuum state

# operators
a  = tensor(destroy(N))

# %%
wp = wc
#xi = -100
xi = -1000*kappa

print 'K = {} MHz; k = {} kHz'.format(xi, kappa)
# Out:
# K = -0.5 MHz; k = 0.0005 kHz

# %%
print 'quality factor: Q = kappa/w = {}'.format(wc/kappa)
# Out:
# quality factor: Q = kappa/w = 12566.3706144

# %%
H0 = wc*a.dag()*a + xi * a.dag() * a.dag() * a * a

# %%
H1 = np.sqrt(kappa)/2.*np.conjugate(alpha)*a
def H1_coeff(t, args):
        return np.exp(+1j*2*np.pi*t)
        #return np.cos(2.*np.pi*t)

H2 = np.sqrt(kappa)/2.*alpha*a.dag()
def H2_coeff(t, args):
        return np.exp(-1j*2*np.pi*t)

# %%
H = [H0, [H1,H1_coeff], [H2,H2_coeff]]
#H = [H0, [H1,H1_coeff]]
#H = [H0, [H1,np.sin(wp*tlist)]]

# %%
c_op_list = []

rate = kappa * (1 + n_th_a)
if rate > 0.0:
    c_op_list.append((np.sqrt(rate) * a + alpha))

#rate = kappa * n_th_a
#if rate > 0.0:
#    c_op_list.append(np.sqrt(rate) * a.dag())

# %%
#mesolve?

# %%
output = mesolve(H, psi0, tlist, c_op_list, [a.dag() * a], options=Options(nsteps=100000), progress_bar = True)
# Out:
# 10.0%. Run time:   1.90s. Est. time left: 00:00:00:17
# 20.0%. Run time:   3.77s. Est. time left: 00:00:00:15
# 30.0%. Run time:   5.63s. Est. time left: 00:00:00:13
# 40.0%. Run time:   7.50s. Est. time left: 00:00:00:11
# 50.0%. Run time:   9.35s. Est. time left: 00:00:00:09
# 60.0%. Run time:  11.34s. Est. time left: 00:00:00:07
# 70.0%. Run time:  13.26s. Est. time left: 00:00:00:05
# 80.0%. Run time:  15.13s. Est. time left: 00:00:00:03
# 90.0%. Run time:  17.01s. Est. time left: 00:00:00:01
# Total run time:  18.79s

# %%
#output2 = mesolve(H, psi0, tlist, c_op_list, [a.dag() * a], options=Options(nsteps=100000))

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(tlist, output.expect[0], label="Cavity")
ax.legend()
ax.set_xlabel(r'$\mathrm{Time}\,\,t\,\mathrm{[ns]}$')
ax.set_ylabel('Occupation probability')
ax.set_title('Cavity Rabi oscillations')

# %%
tlist = np.linspace(0,400,300)

# %%
wc = 1.0  * 2 * np.pi   # cavity frequency
#wa = 1.0  * 2 * np.pi  # atom frequency
#g  = 0.05 * 2 * np.pi  # coupling strength
kappa = 5 * 10**-4          # cavity dissipation rate
gamma = 0.00           # atom dissipation rate
alpha = 5
N = 3*alpha                # number of cavity fock states
n_th_a = 0.0           # temperature in frequency units
use_rwa = True

# %%
# intial state
psi0 = tensor(basis(N,0))    # start with a cavity in vacuum state

# operators
a  = tensor(destroy(N))

# %%
out = []
for alpha in [2,5,10]:
    for k in [10,100,1000]:
        xi = -k*kappa
        H0 = wc*a.dag()*a + xi * a.dag() * a.dag() * a * a 
        H1 = np.sqrt(kappa)/2.*np.conjugate(alpha)*a
        def H1_coeff(t, args):
            return np.exp(+1j*2*np.pi*t)
            #return np.cos(2.*np.pi*t)

        H2 = np.sqrt(kappa)/2.*alpha*a.dag()
        def H2_coeff(t, args):
            return np.exp(-1j*2*np.pi*t)

        H = [H0, [H1,H1_coeff], [H2,H2_coeff]]

        c_op_list = []

        rate = kappa * (1 + n_th_a)
        if rate > 0.0:
            c_op_list.append((np.sqrt(rate) * a + alpha))

        #rate = kappa * n_th_a
        #if rate > 0.0:
        #    c_op_list.append(np.sqrt(rate) * a.dag())

        out.append(mesolve(H, psi0, tlist, c_op_list, [a.dag() * a], options=Options(nsteps=100000), progress_bar = True))
# Out:
# 10.0%. Run time:   2.90s. Est. time left: 00:00:00:26
# 20.0%. Run time:   6.08s. Est. time left: 00:00:00:24
# 30.0%. Run time:   9.30s. Est. time left: 00:00:00:21
# 40.0%. Run time:  12.36s. Est. time left: 00:00:00:18
# 50.0%. Run time:  15.42s. Est. time left: 00:00:00:15
# 60.0%. Run time:  18.49s. Est. time left: 00:00:00:12
# 70.0%. Run time:  21.56s. Est. time left: 00:00:00:09
# 80.0%. Run time:  24.60s. Est. time left: 00:00:00:06
# 90.0%. Run time:  27.67s. Est. time left: 00:00:00:03
# Total run time:  30.63s
# 10.0%. Run time:   2.70s. Est. time left: 00:00:00:24
# 20.0%. Run time:   5.45s. Est. time left: 00:00:00:21
# 30.0%. Run time:   8.22s. Est. time left: 00:00:00:19
# 40.0%. Run time:  10.98s. Est. time left: 00:00:00:16
# 50.0%. Run time:  13.74s. Est. time left: 00:00:00:13
# 60.0%. Run time:  16.51s. Est. time left: 00:00:00:11
# 70.0%. Run time:  19.29s. Est. time left: 00:00:00:08
# 80.0%. Run time:  22.08s. Est. time left: 00:00:00:05
# 90.0%. Run time:  24.84s. Est. time left: 00:00:00:02
# Total run time:  27.63s
# 10.0%. Run time:   0.83s. Est. time left: 00:00:00:07
# 20.0%. Run time:   1.66s. Est. time left: 00:00:00:06
# 30.0%. Run time:   2.60s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.60s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.57s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.54s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.51s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.49s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.47s. Est. time left: 00:00:00:00
# Total run time:   9.42s
# 10.0%. Run time:   3.38s. Est. time left: 00:00:00:30
# 20.0%. Run time:   7.56s. Est. time left: 00:00:00:30
# 30.0%. Run time:  12.00s. Est. time left: 00:00:00:27
# 40.0%. Run time:  16.76s. Est. time left: 00:00:00:25
# 50.0%. Run time:  21.23s. Est. time left: 00:00:00:21
# 60.0%. Run time:  25.92s. Est. time left: 00:00:00:17
# 70.0%. Run time:  30.68s. Est. time left: 00:00:00:13
# 80.0%. Run time:  35.43s. Est. time left: 00:00:00:08
# 90.0%. Run time:  40.19s. Est. time left: 00:00:00:04
# Total run time:  44.83s
# 10.0%. Run time:   2.83s. Est. time left: 00:00:00:25
# 20.0%. Run time:   5.75s. Est. time left: 00:00:00:22
# 30.0%. Run time:   8.65s. Est. time left: 00:00:00:20
# 40.0%. Run time:  11.54s. Est. time left: 00:00:00:17
# 50.0%. Run time:  14.45s. Est. time left: 00:00:00:14
# 60.0%. Run time:  17.33s. Est. time left: 00:00:00:11
# 70.0%. Run time:  20.24s. Est. time left: 00:00:00:08
# 80.0%. Run time:  23.12s. Est. time left: 00:00:00:05
# 90.0%. Run time:  26.03s. Est. time left: 00:00:00:02
# Total run time:  28.84s
# 10.0%. Run time:   0.91s. Est. time left: 00:00:00:08
# 20.0%. Run time:   1.84s. Est. time left: 00:00:00:07
# 30.0%. Run time:   2.77s. Est. time left: 00:00:00:06
# 40.0%. Run time:   3.70s. Est. time left: 00:00:00:05
# 50.0%. Run time:   4.64s. Est. time left: 00:00:00:04
# 60.0%. Run time:   5.59s. Est. time left: 00:00:00:03
# 70.0%. Run time:   6.52s. Est. time left: 00:00:00:02
# 80.0%. Run time:   7.46s. Est. time left: 00:00:00:01
# 90.0%. Run time:   8.39s. Est. time left: 00:00:00:00
# Total run time:   9.29s
# 10.0%. Run time:   4.22s. Est. time left: 00:00:00:37
# 20.0%. Run time:   9.48s. Est. time left: 00:00:00:37
# 30.0%. Run time:  15.11s. Est. time left: 00:00:00:35
# 40.0%. Run time:  20.78s. Est. time left: 00:00:00:31
# 50.0%. Run time:  26.50s. Est. time left: 00:00:00:26
# 60.0%. Run time:  32.17s. Est. time left: 00:00:00:21
# 70.0%. Run time:  37.82s. Est. time left: 00:00:00:16
# 80.0%. Run time:  43.45s. Est. time left: 00:00:00:10
# 90.0%. Run time:  49.09s. Est. time left: 00:00:00:05
# Total run time:  54.53s
# 10.0%. Run time:   2.80s. Est. time left: 00:00:00:25
# 20.0%. Run time:   5.64s. Est. time left: 00:00:00:22
# 30.0%. Run time:   8.47s. Est. time left: 00:00:00:19
# 40.0%. Run time:  11.32s. Est. time left: 00:00:00:16
# 50.0%. Run time:  14.15s. Est. time left: 00:00:00:14
# 60.0%. Run time:  16.99s. Est. time left: 00:00:00:11
# 70.0%. Run time:  19.80s. Est. time left: 00:00:00:08
# 80.0%. Run time:  22.64s. Est. time left: 00:00:00:05
# 90.0%. Run time:  25.47s. Est. time left: 00:00:00:02
# Total run time:  28.24s
# 10.0%. Run time:   1.11s. Est. time left: 00:00:00:09
# 20.0%. Run time:   2.24s. Est. time left: 00:00:00:08
# 30.0%. Run time:   3.38s. Est. time left: 00:00:00:07
# 40.0%. Run time:   4.52s. Est. time left: 00:00:00:06
# 50.0%. Run time:   5.66s. Est. time left: 00:00:00:05
# 60.0%. Run time:   6.80s. Est. time left: 00:00:00:04
# 70.0%. Run time:   7.91s. Est. time left: 00:00:00:03
# 80.0%. Run time:   9.02s. Est. time left: 00:00:00:02
# 90.0%. Run time:  10.13s. Est. time left: 00:00:00:01
# Total run time:  11.21s

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(tlist, out[2].expect[0], label=r'$K/\kappa = 1000; \alpha = 2$', lw = 2)
ax.plot(tlist, out[5].expect[0], label=r'$K/\kappa = 1000; \alpha = 5$', lw = 2, ls = '--')
ax.plot(tlist, out[8].expect[0], label=r'$K/\kappa = 1000;  \alpha = 10$', lw = 2, ls = '-.')
ax.set_xlabel(r'$\mathrm{Time}\,\,t$')
ax.set_ylabel(r'$<a^\dagger a>$')
#ax.set_title(r'$K\,=\,{}\,\mathrm{{MHz}};\,\,\kappa\,=\,{}\,\mathrm{{kHz}}$'.format(xi,kappa));
ax.legend(loc = 'upper center',ncol = 2,  bbox_to_anchor = (0.5,-0.25))

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(tlist, out[0].expect[0], label=r'$K/\kappa = 10; \alpha = 2$', lw = 2)
ax.plot(tlist, out[1].expect[0], label=r'$K/\kappa = 100; \alpha = 2$', lw = 2, ls = '--')
ax.plot(tlist, out[2].expect[0], label=r'$K/\kappa = 1000;  \alpha = 2$', lw = 2, ls = '-.')
ax.set_xlabel(r'$\mathrm{Time}\,\,t$')
ax.set_ylabel(r'$<a^\dagger a>$')
#ax.set_title(r'$K\,=\,{}\,\mathrm{{MHz}};\,\,\kappa\,=\,{}\,\mathrm{{kHz}}$'.format(xi,kappa));
ax.legend(loc = 'upper center',ncol = 2,  bbox_to_anchor = (0.5,-0.25))

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(tlist, out[0].expect[0], label=r'$K/\kappa = 10; \alpha = 2$', lw = 2)
ax.plot(tlist, out[3].expect[0], label=r'$K/\kappa = 10; \alpha = 5$', lw = 2, ls = '--')
ax.plot(tlist, out[6].expect[0], label=r'$K/\kappa = 10;  \alpha = 10$', lw = 2, ls = '-.')
ax.set_xlabel(r'$\mathrm{Time}\,\,t$')
ax.set_ylabel(r'$<a^\dagger a>$')
#ax.set_title(r'$K\,=\,{}\,\mathrm{{MHz}};\,\,\kappa\,=\,{}\,\mathrm{{kHz}}$'.format(xi,kappa));
ax.legend(loc = 'upper center',ncol = 2,  bbox_to_anchor = (0.5,-0.25))

# %%
wc = 1.0  * 2 * np.pi  # cavity frequency
wa = 1.0  * 2 * np.pi  # atom frequency
g  = 0.05 * 2 * np.pi  # coupling strength
kappa = 0.005          # cavity dissipation rate
gamma = 0.05           # atom dissipation rate
N = 15                 # number of cavity fock states
n_th_a = 0.0           # temperature in frequency units
use_rwa = True

tlist = np.linspace(0,25,100)

# %%
# intial state
psi0 = tensor(basis(N,0), basis(2,1))    # start with an excited atom

# operators
a  = tensor(destroy(N), qeye(2))
sm = tensor(qeye(N), destroy(2))

# Hamiltonian
if use_rwa:
    H = wc * a.dag() * a + wa * sm.dag() * sm + g * (a.dag() * sm + a * sm.dag())
else:
    H = wc * a.dag() * a + wa * sm.dag() * sm + g * (a.dag() + a) * (sm + sm.dag())

# %%
c_op_list = []

rate = kappa * (1 + n_th_a)
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * a)

rate = kappa * n_th_a
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * a.dag())

rate = gamma
if rate > 0.0:
    c_op_list.append(np.sqrt(rate) * sm)

# %%
output = mesolve(H, psi0, tlist, c_op_list, [a.dag() * a, sm.dag() * sm])

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.plot(tlist, output.expect[0], label="Cavity")
ax.plot(tlist, output.expect[1], label="Atom excited state")
ax.legend()
ax.set_xlabel('Time')
ax.set_ylabel('Occupation probability')
ax.set_title('Vacuum Rabi oscillations');

# %%
def GAMMA(kappa,gamma,alpha_in,, K):
    tau = kappa + gamma
    alpha_in_tilde = np.sqrt(kappa)*alpha_in/tau
    delta = (omega_p - omega_0)/tau
    epsilon= np.abs(alpha_in_tilde)**2.*K/tau
    n = np.abs(alpha)**2./np.abs(alpha_in_tilde)**2.
    return (kappa/tau)*1/(0.5-i*delta+i*epsilon*n)-1.
# Out:
#   File "<ipython-input-170-06100868d544>", line 1
#     def GAMMA(kappa,gamma,alpha_in,, K):
#                                    ^
# SyntaxError: invalid syntax
